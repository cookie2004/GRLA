# %%
# %pip install baselines
# Out:
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\cooki_l8i2983\\AppData\\Local\\Temp\\pip-install-8c8fghwt\\mujoco-py\\setup.py'"'"'; __file__='"'"'C:\\Users\\cooki_l8i2983\\AppData\\Local\\Temp\\pip-install-8c8fghwt\\mujoco-py\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-wheel-s33_l_7b'
#        cwd: C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-8c8fghwt\mujoco-py\
#   Complete output (54 lines):
#   running bdist_wheel
#   running build
#
#   You appear to be missing MuJoCo.  We expected to find the file here: C:\Users\cooki_l8i2983\.mujoco\mjpro150
#
#   This package only provides python bindings, the library must be installed separately.
#
#   Please follow the instructions on the README to install MuJoCo
#
#       https://github.com/openai/mujoco-py#install-mujoco
#
#   Which can be downloaded from the website
#
#       https://www.roboti.us/index.html
#
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-8c8fghwt\mujoco-py\setup.py", line 32, in <module>
#       setup(
#     File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\site-packages\setuptools\__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\distutils\core.py", line 148, in setup
#       dist.run_commands()
#     File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\distutils\dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\site-packages\wheel\bdist_wheel.py", line 290, in run
#       self.run_command('build')
#     File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-8c8fghwt\mujoco-py\setup.py", line 28, in run
#       import mujoco_py  # noqa: force build
#     File "C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-8c8fghwt\mujoco-py\mujoco_py\__init__.py", line 3, in <module>
#       from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#     File "C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-8c8fghwt\mujoco-py\mujoco_py\builder.py", line 502, in <module>
#       mjpro_path, key_path = discover_mujoco()
#     File "C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-8c8fghwt\mujoco-py\mujoco_py\utils.py", line 93, in discover_mujoco
#       raise Exception(message)
#   Exception:
#   You appear to be missing MuJoCo.  We expected to find the file here: C:\Users\cooki_l8i2983\.mujoco\mjpro150
#
#   This package only provides python bindings, the library must be installed separately.
#
#   Please follow the instructions on the README to install MuJoCo
#
#       https://github.com/openai/mujoco-py#install-mujoco
#
#   Which can be downloaded from the website
#
#       https://www.roboti.us/index.html
#
#   ----------------------------------------
#   ERROR: Failed building wheel for mujoco-py
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'C:\\Users\\cooki_l8i2983\\Anaconda3\\envs\\VGBOT\\Lib\\site-packages\\~-mpy\\.libs\\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll'
# Consider using the `--user` option or check the permissions.
# Requirement already satisfied: baselines in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (0.1.5)
# Requirement already satisfied: tqdm in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (4.59.0)
# Requirement already satisfied: zmq in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (0.0.0)
# Requirement already satisfied: joblib in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (1.0.1)
# Requirement already satisfied: click in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (7.1.2)
# Requirement already satisfied: mpi4py in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (3.0.3)
# Requirement already satisfied: gym[atari,classic_control,mujoco,robotics] in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (0.18.0)
# Requirement already satisfied: cloudpickle in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (1.6.0)
# Requirement already satisfied: tensorflow>=1.4.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (2.3.0)
# Requirement already satisfied: scipy in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (1.6.0)
# Requirement already satisfied: progressbar2 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (3.53.1)
# Requirement already satisfied: dill in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (0.3.3)
# Requirement already satisfied: pyzmq in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from zmq->baselines) (19.0.2)
# Requirement already satisfied: opencv-python>=3.; extra == "atari" in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from gym[atari,classic_control,mujoco,robotics]->baselines) (4.5.1.48)
# Requirement already satisfied: atari-py~=0.2.0; extra == "atari" in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from gym[atari,classic_control,mujoco,robotics]->baselines) (0.2.6)
# Requirement already satisfied: imageio; extra == "mujoco" in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from gym[atari,classic_control,mujoco,robotics]->baselines) (2.9.0)
# Collecting mujoco-py<2.0,>=1.50; extra == "mujoco"
#   Using cached mujoco-py-1.50.1.68.tar.gz (120 kB)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (0.11.0)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (2.4.1)
# Requirement already satisfied: google-pasta>=0.1.8 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (0.2.0)
# Collecting numpy<1.19.0,>=1.16.0
#   Downloading numpy-1.18.5-cp38-cp38-win_amd64.whl (12.8 MB)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (1.12.1)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (3.14.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (1.15.0)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (1.35.0)
# Collecting gast==0.3.3
#   Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: wheel>=0.26 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (0.35.1)
# Collecting tensorflow-estimator<2.4.0,>=2.3.0
#   Using cached tensorflow_estimator-2.3.0-py2.py3-none-any.whl (459 kB)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (1.1.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (1.1.2)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (2.10.0)
# Requirement already satisfied: python-utils>=2.3.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from progressbar2->baselines) (2.5.6)
# Requirement already satisfied: pillow in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from imageio; extra == "mujoco"->gym[atari,classic_control,mujoco,robotics]->baselines) (7.2.0)
# Requirement already satisfied: glfw>=1.4.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from mujoco-py<2.0,>=1.50; extra == "mujoco"->gym[atari,classic_control,mujoco,robotics]->baselines) (2.1.0)
# Requirement already satisfied: Cython>=0.27.2 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from mujoco-py<2.0,>=1.50; extra == "mujoco"->gym[atari,classic_control,mujoco,robotics]->baselines) (0.29.22)
# Requirement already satisfied: cffi>=1.10 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from mujoco-py<2.0,>=1.50; extra == "mujoco"->gym[atari,classic_control,mujoco,robotics]->baselines) (1.14.3)
# Requirement already satisfied: lockfile>=0.12.2 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from mujoco-py<2.0,>=1.50; extra == "mujoco"->gym[atari,classic_control,mujoco,robotics]->baselines) (0.12.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (1.24.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (50.3.0.post20201006)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (1.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (2.25.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (3.3.3)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (0.4.1)
# Requirement already satisfied: pycparser in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from cffi>=1.10->mujoco-py<2.0,>=1.50; extra == "mujoco"->gym[atari,classic_control,mujoco,robotics]->baselines) (2.20)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (4.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (0.2.7)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (4.2.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (1.26.3)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (2.10)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (3.0.1)
# Building wheels for collected packages: mujoco-py
#   Building wheel for mujoco-py (setup.py): started
#   Building wheel for mujoco-py (setup.py): finished with status 'error'
#   Running setup.py clean for mujoco-py
# Failed to build mujoco-py
# Installing collected packages: numpy, mujoco-py, opt-einsum, gast, tensorflow-estimator
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# Requirement already satisfied: baselines in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (0.1.5)
# Requirement already satisfied: progressbar2 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (3.53.1)
# Requirement already satisfied: cloudpickle in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (1.6.0)
# Requirement already satisfied: click in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (7.1.2)
# Requirement already satisfied: mpi4py in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (3.0.3)
# Requirement already satisfied: tensorflow>=1.4.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (2.3.0)
# Requirement already satisfied: dill in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (0.3.3)
# Requirement already satisfied: scipy in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (1.6.0)
# Requirement already satisfied: gym[atari,classic_control,mujoco,robotics] in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (0.18.0)
# Requirement already satisfied: tqdm in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (4.59.0)
# Requirement already satisfied: zmq in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (0.0.0)
# Requirement already satisfied: joblib in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from baselines) (1.0.1)
# Requirement already satisfied: python-utils>=2.3.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from progressbar2->baselines) (2.5.6)
# Requirement already satisfied: six in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from progressbar2->baselines) (1.15.0)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (1.12.1)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (0.11.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (2.10.0)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (2.4.1)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (1.1.2)
# Collecting tensorflow-estimator<2.4.0,>=2.3.0
#   Using cached tensorflow_estimator-2.3.0-py2.py3-none-any.whl (459 kB)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (1.35.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.8 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (0.2.0)
# Collecting numpy<1.19.0,>=1.16.0
#   Using cached numpy-1.18.5-cp38-cp38-win_amd64.whl (12.8 MB)
# Collecting gast==0.3.3
#   Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (1.6.3)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (3.14.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorflow>=1.4.0->baselines) (0.35.1)
# Requirement already satisfied: opencv-python>=3.; extra == "atari" in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from gym[atari,classic_control,mujoco,robotics]->baselines) (4.5.1.48)
# Requirement already satisfied: atari-py~=0.2.0; extra == "atari" in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from gym[atari,classic_control,mujoco,robotics]->baselines) (0.2.6)
# Collecting mujoco-py<2.0,>=1.50; extra == "mujoco"
#   Using cached mujoco-py-1.50.1.68.tar.gz (120 kB)
# Requirement already satisfied: imageio; extra == "mujoco" in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from gym[atari,classic_control,mujoco,robotics]->baselines) (2.9.0)
# Requirement already satisfied: pyzmq in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from zmq->baselines) (19.0.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (3.3.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (2.25.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (1.8.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (1.24.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (50.3.0.post20201006)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (0.4.1)
# Requirement already satisfied: glfw>=1.4.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from mujoco-py<2.0,>=1.50; extra == "mujoco"->gym[atari,classic_control,mujoco,robotics]->baselines) (2.1.0)
# Requirement already satisfied: Cython>=0.27.2 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from mujoco-py<2.0,>=1.50; extra == "mujoco"->gym[atari,classic_control,mujoco,robotics]->baselines) (0.29.22)
# Requirement already satisfied: cffi>=1.10 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from mujoco-py<2.0,>=1.50; extra == "mujoco"->gym[atari,classic_control,mujoco,robotics]->baselines) (1.14.3)
# Requirement already satisfied: lockfile>=0.12.2 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from mujoco-py<2.0,>=1.50; extra == "mujoco"->gym[atari,classic_control,mujoco,robotics]->baselines) (0.12.2)
# Requirement already satisfied: pillow in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from imageio; extra == "mujoco"->gym[atari,classic_control,mujoco,robotics]->baselines) (7.2.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (1.26.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (3.0.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (4.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (0.2.7)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from cffi>=1.10->mujoco-py<2.0,>=1.50; extra == "mujoco"->gym[atari,classic_control,mujoco,robotics]->baselines) (2.20)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\cooki_l8i2983\anaconda3\envs\vgbot\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=1.4.0->baselines) (3.0.1)
# Building wheels for collected packages: mujoco-py
#   Building wheel for mujoco-py (setup.py): started
#   Building wheel for mujoco-py (setup.py): finished with status 'error'
#   Running setup.py clean for mujoco-py
# Failed to build mujoco-py
# Installing collected packages: tensorflow-estimator, numpy, gast, opt-einsum, mujoco-py
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Can't uninstall 'numpy'. No files were found to uninstall.
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt-einsum 0+untagged.61.gd905544.dirty
#     Uninstalling opt-einsum-0+untagged.61.gd905544.dirty:
#       Successfully uninstalled opt-einsum-0+untagged.61.gd905544.dirty
#     Running setup.py install for mujoco-py: started
#     Running setup.py install for mujoco-py: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\cooki_l8i2983\\AppData\\Local\\Temp\\pip-install-_qm1is13\\mujoco-py\\setup.py'"'"'; __file__='"'"'C:\\Users\\cooki_l8i2983\\AppData\\Local\\Temp\\pip-install-_qm1is13\\mujoco-py\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-wheel-nrx9nhl8'
#        cwd: C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-_qm1is13\mujoco-py\
#   Complete output (54 lines):
#   running bdist_wheel
#   running build
#
#   You appear to be missing MuJoCo.  We expected to find the file here: C:\Users\cooki_l8i2983\.mujoco\mjpro150
#
#   This package only provides python bindings, the library must be installed separately.
#
#   Please follow the instructions on the README to install MuJoCo
#
#       https://github.com/openai/mujoco-py#install-mujoco
#
#   Which can be downloaded from the website
#
#       https://www.roboti.us/index.html
#
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-_qm1is13\mujoco-py\setup.py", line 32, in <module>
#       setup(
#     File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\site-packages\setuptools\__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\distutils\core.py", line 148, in setup
#       dist.run_commands()
#     File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\distutils\dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\site-packages\wheel\bdist_wheel.py", line 290, in run
#       self.run_command('build')
#     File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-_qm1is13\mujoco-py\setup.py", line 28, in run
#       import mujoco_py  # noqa: force build
#     File "C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-_qm1is13\mujoco-py\mujoco_py\__init__.py", line 3, in <module>
#       from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#     File "C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-_qm1is13\mujoco-py\mujoco_py\builder.py", line 502, in <module>
#       mjpro_path, key_path = discover_mujoco()
#     File "C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-_qm1is13\mujoco-py\mujoco_py\utils.py", line 93, in discover_mujoco
#       raise Exception(message)
#   Exception:
#   You appear to be missing MuJoCo.  We expected to find the file here: C:\Users\cooki_l8i2983\.mujoco\mjpro150
#
#   This package only provides python bindings, the library must be installed separately.
#
#   Please follow the instructions on the README to install MuJoCo
#
#       https://github.com/openai/mujoco-py#install-mujoco
#
#   Which can be downloaded from the website
#
#       https://www.roboti.us/index.html
#
#   ----------------------------------------
#   ERROR: Failed building wheel for mujoco-py
# WARNING: Error parsing requirements for numpy: [Errno 2] No such file or directory: 'c:\\users\\cooki_l8i2983\\anaconda3\\envs\\vgbot\\lib\\site-packages\\numpy-1.19.5.dist-info\\METADATA'
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\cooki_l8i2983\\AppData\\Local\\Temp\\pip-install-_qm1is13\\mujoco-py\\setup.py'"'"'; __file__='"'"'C:\\Users\\cooki_l8i2983\\AppData\\Local\\Temp\\pip-install-_qm1is13\\mujoco-py\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-record-t5bkm4qn\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\Include\mujoco-py'
#          cwd: C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-_qm1is13\mujoco-py\
#     Complete output (56 lines):
#     running install
#     running build
#
#     You appear to be missing MuJoCo.  We expected to find the file here: C:\Users\cooki_l8i2983\.mujoco\mjpro150
#
#     This package only provides python bindings, the library must be installed separately.
#
#     Please follow the instructions on the README to install MuJoCo
#
#         https://github.com/openai/mujoco-py#install-mujoco
#
#     Which can be downloaded from the website
#
#         https://www.roboti.us/index.html
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-_qm1is13\mujoco-py\setup.py", line 32, in <module>
#         setup(
#       File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\site-packages\setuptools\__init__.py", line 153, in setup
#         return distutils.core.setup(**attrs)
#       File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\distutils\core.py", line 148, in setup
#         dist.run_commands()
#       File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\distutils\dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\site-packages\setuptools\command\install.py", line 61, in run
#         return orig.install.run(self)
#       File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\distutils\command\install.py", line 545, in run
#         self.run_command('build')
#       File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-_qm1is13\mujoco-py\setup.py", line 28, in run
#         import mujoco_py  # noqa: force build
#       File "C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-_qm1is13\mujoco-py\mujoco_py\__init__.py", line 3, in <module>
#         from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#       File "C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-_qm1is13\mujoco-py\mujoco_py\builder.py", line 502, in <module>
#         mjpro_path, key_path = discover_mujoco()
#       File "C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-install-_qm1is13\mujoco-py\mujoco_py\utils.py", line 93, in discover_mujoco
#         raise Exception(message)
#     Exception:
#     You appear to be missing MuJoCo.  We expected to find the file here: C:\Users\cooki_l8i2983\.mujoco\mjpro150
#
#     This package only provides python bindings, the library must be installed separately.
#
#     Please follow the instructions on the README to install MuJoCo
#
#         https://github.com/openai/mujoco-py#install-mujoco
#
#     Which can be downloaded from the website
#
#         https://www.roboti.us/index.html
#
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\cooki_l8i2983\\AppData\\Local\\Temp\\pip-install-_qm1is13\\mujoco-py\\setup.py'"'"'; __file__='"'"'C:\\Users\\cooki_l8i2983\\AppData\\Local\\Temp\\pip-install-_qm1is13\\mujoco-py\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\cooki_l8i2983\AppData\Local\Temp\pip-record-t5bkm4qn\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\cooki_l8i2983\Anaconda3\envs\VGBOT\Include\mujoco-py' Check the logs for full command output.

# %%
from baselines.common.atari_wrappers import make_atari, wrap_deepmind
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pylab as plt
# Configuration paramaters for the whole setup
seed = 42
gamma = 0.99  # Discount factor for past rewards
epsilon = 1.0  # Epsilon greedy parameter
epsilon_min = 0.1  # Minimum epsilon greedy parameter
epsilon_max = 1.0  # Maximum epsilon greedy parameter
epsilon_interval = (
    epsilon_max - epsilon_min
)  # Rate at which to reduce chance of random action being taken
batch_size = 32  # Size of batch taken from replay buffer
max_steps_per_episode = 10000

# Use the Baseline Atari environment because of Deepmind helper functions
env = make_atari("BreakoutNoFrameskip-v4")
# Warp the frames, grey scale, stake four frame and scale to smaller ratio
env = wrap_deepmind(env, frame_stack=True, scale=True)
env.seed(seed)
# Out:
# [42, 742738649]

# %%
num_actions = 4


def create_q_model():
    # Network defined by the Deepmind paper
    inputs = layers.Input(shape=(84, 84, 4,))

    # Convolutions on the frames on the screen
    layer1 = layers.Conv2D(32, 8, strides=4, activation="relu")(inputs)
    layer2 = layers.Conv2D(64, 4, strides=2, activation="relu")(layer1)
    layer3 = layers.Conv2D(64, 3, strides=1, activation="relu")(layer2)

    layer4 = layers.Flatten()(layer3)

    layer5 = layers.Dense(512, activation="relu")(layer4)
    action = layers.Dense(num_actions, activation="linear")(layer5)

    return keras.Model(inputs=inputs, outputs=action)


# The first model makes the predictions for Q-values which are used to
# make a action.
model = create_q_model()
# Build a target model for the prediction of future rewards.
# The weights of a target model get updated every 10000 steps thus when the
# loss between the Q-values is calculated the target Q-value is stable.
model_target = create_q_model()

# %%
# In the Deepmind paper they use RMSProp however then Adam optimizer
# improves training time
optimizer = keras.optimizers.Adam(learning_rate=0.00025, clipnorm=1.0)

# Experience replay buffers
action_history = []
state_history = []
state_next_history = []
rewards_history = []
done_history = []
episode_reward_history = []
running_reward = 0
episode_count = 0
frame_count = 0
# Number of frames to take random action and observe output
epsilon_random_frames = 50000
# Number of frames for exploration
epsilon_greedy_frames = 1000000.0
# Maximum replay length
# Note: The Deepmind paper suggests 1000000 however this causes memory issues
max_memory_length = 100000
# Train the model after 4 actions
update_after_actions = 4
# How often to update the target network
update_target_network = 10000
# Using huber loss for stability
loss_function = keras.losses.Huber()
loss_history = []
return_history = []
while True:  # Run until solved
    state = np.array(env.reset())
    episode_reward = 0

    for timestep in range(1, max_steps_per_episode):
        # env.render(); Adding this line would show the attempts
        # of the agent in a pop up window.
        frame_count += 1

        # Use epsilon-greedy for exploration
        if frame_count < epsilon_random_frames or epsilon > np.random.rand(1)[0]:
            # Take random action
            action = np.random.choice(num_actions)
        else:
            # Predict action Q-values
            # From environment state
            state_tensor = tf.convert_to_tensor(state)
            state_tensor = tf.expand_dims(state_tensor, 0)
            action_probs = model(state_tensor, training=False)
            # Take best action
            action = tf.argmax(action_probs[0]).numpy()

        # Decay probability of taking random action
        epsilon -= epsilon_interval / epsilon_greedy_frames
        epsilon = max(epsilon, epsilon_min)

        # Apply the sampled action in our environment
        state_next, reward, done, _ = env.step(action)
        state_next = np.array(state_next)

        episode_reward += reward

        # Save actions and states in replay buffer
        action_history.append(action)
        state_history.append(state)
        state_next_history.append(state_next)
        done_history.append(done)
        rewards_history.append(reward)
        state = state_next

        # Update every fourth frame and once batch size is over 32
        if frame_count % update_after_actions == 0 and len(done_history) > batch_size:

            # Get indices of samples for replay buffers
            indices = np.random.choice(range(len(done_history)), size=batch_size)

            # Using list comprehension to sample from replay buffer
            state_sample = np.array([state_history[i] for i in indices])
            state_next_sample = np.array([state_next_history[i] for i in indices])
            rewards_sample = [rewards_history[i] for i in indices]
            action_sample = [action_history[i] for i in indices]
            done_sample = tf.convert_to_tensor(
                [float(done_history[i]) for i in indices]
            )

            # Build the updated Q-values for the sampled future states
            # Use the target model for stability
            future_rewards = model_target.predict(state_next_sample)
            # Q value = reward + discount factor * expected future reward
            updated_q_values = rewards_sample + gamma * tf.reduce_max(
                future_rewards, axis=1
            )

            # If final frame set the last value to -1
            updated_q_values = updated_q_values * (1 - done_sample) - done_sample

            # Create a mask so we only calculate loss on the updated Q-values
            masks = tf.one_hot(action_sample, num_actions)

            with tf.GradientTape() as tape:
                # Train the model on the states and updated Q-values
                q_values = model(state_sample)

                # Apply the masks to the Q-values to get the Q-value for action taken
                q_action = tf.reduce_sum(tf.multiply(q_values, masks), axis=1)
                # Calculate loss between new Q-value and old Q-value
                loss = loss_function(updated_q_values, q_action)
                loss_history.append(loss)
            # Backpropagation
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))

        if frame_count % update_target_network == 0:
            # update the the target network with new weights
            model_target.set_weights(model.get_weights())
            # Log details
            template = "running reward: {:.2f} at episode {}, frame count {}"
            print(template.format(running_reward, episode_count, frame_count))

        # Limit the state and reward history
        if len(rewards_history) > max_memory_length:
            del rewards_history[:1]
            del state_history[:1]
            del state_next_history[:1]
            del action_history[:1]
            del done_history[:1]

        if done:
            break

    # Update running reward to check condition for solving
    episode_reward_history.append(episode_reward)
    if len(episode_reward_history) > 100:
        del episode_reward_history[:1]
    running_reward = np.mean(episode_reward_history)
    plt.figure(figsize=(5,5))
    plt.plot(np.arange(len(episode_reward_history)), episode_reward_history)
    plt.xlabel('Training Step')
    plt.ylabel('Loss')
    plt.show()    
    
    plt.figure(figsize=(5,5))
    plt.plot(np.arange(len(loss_history)), loss_history)
    plt.xlabel('Training Step')
    plt.ylabel('Loss')
    plt.show()
    episode_count += 1

    if running_reward > 40:  # Condition to consider the task solved
        print("Solved at episode {}!".format(episode_count))
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-c3478ed7fd67> in <module>
#     107                 loss_history.append(loss)
#     108             # Backpropagation
# --> 109             grads = tape.gradient(loss, model.trainable_variables)
#     110             optimizer.apply_gradients(zip(grads, model.trainable_variables))
#     111
#
# ~\Anaconda3\envs\VGBOT\lib\site-packages\tensorflow\python\eager\backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1065                           for x in nest.flatten(output_gradients)]
#    1066
# -> 1067     flat_grad = imperative_grad.imperative_grad(
#    1068         self._tape,
#    1069         flat_targets,
#
# ~\Anaconda3\envs\VGBOT\lib\site-packages\tensorflow\python\eager\imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      69         "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
#      70
# ---> 71   return pywrap_tfe.TFE_Py_TapeGradient(
#      72       tape._tape,  # pylint: disable=protected-access
#      73       target,
#
# ~\Anaconda3\envs\VGBOT\lib\site-packages\tensorflow\python\eager\backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     160       gradient_name_scope += forward_pass_name_scope + "/"
#     161     with ops.name_scope(gradient_name_scope):
# --> 162       return grad_fn(mock_op, *out_grads)
#     163   else:
#     164     return grad_fn(mock_op, *out_grads)
#
# ~\Anaconda3\envs\VGBOT\lib\site-packages\tensorflow\python\ops\math_grad.py in _MatMulGrad(op, grad)
#    1689   b = math_ops.conj(op.inputs[1])
#    1690   if not t_a and not t_b:
# -> 1691     grad_a = gen_math_ops.mat_mul(grad, b, transpose_b=True)
#    1692     grad_b = gen_math_ops.mat_mul(a, grad, transpose_a=True)
#    1693   elif not t_a and t_b:
#
# ~\Anaconda3\envs\VGBOT\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in mat_mul(a, b, transpose_a, transpose_b, name)
#    5615   if tld.is_eager:
#    5616     try:
# -> 5617       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    5618         _ctx._context_handle, tld.device_name, "MatMul", name,
#    5619         tld.op_callbacks, a, b, "transpose_a", transpose_a, "transpose_b",
#
# KeyboardInterrupt:

# %%
plt.figure()
plt.imshow(state_history[0][:,:,0])

plt.figure()
plt.imshow(state_history[0][:,:,1])

plt.figure()
plt.imshow(state_history[0][:,:,2])

plt.figure()
plt.imshow(state_history[0][:,:,3])
